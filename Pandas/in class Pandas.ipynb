# %%
- Python
    -variables    storing data
    -data types - int float string -string list dictionary sets range
    - functions - create reusable code, lots of line of code in one place
    - classes - help us containerise code, box things up, 

- Libraries
    -numPy - **arrays** we can create matrices, numerical calculation
    - pandas - **DataFames** store data like spread sheets, excel sheets, we can manipulate those tables.

- Machine Learning
        - data - clean data, analyse data, play with data
        - feed to the machine
        - show the machine what is right, what is wrong (learns, creates its own patterns)
        - then you ask questions, and get answers
# Out:
#   Cell In[2], line 2
#     -variables    storing data
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# #### dictionaries???
#
# - we will try to create a dictionary
# - data types with keys and values

# %%
# create a small dictionary
# names of 4 students, and their marks

# key : value

students_grades = {
    'name':['Idrees','Amri','Ali','Abu'],
    'maths':[90,85,97,89],
    'english':[89,86,77,88],
    'science':[78,89,98,91]}

print(students_grades)
# Out:
# {'name': ['Idrees', 'Amri', 'Ali', 'Abu'], 'maths': [90, 85, 97, 89], 'english': [89, 86, 77, 88], 'science': [78, 89, 98, 91]}

# %%
students_grades["name"]

students_grades["name"][2]
# Out:
# 'Ali'

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\nec\appdata\local\python\pythoncore-3.14-64\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\nec\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\nec\appdata\roaming\python\python314\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\nec\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\nec\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\nec\appdata\roaming\python\python314\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

df = pd.DataFrame(students_grades)

df
# Out:
#      name  maths  english  science
# 0  Idrees     90       89       78
# 1    Amri     85       86       89
# 2     Ali     97       77       98
# 3     Abu     89       88       91

# %%
# Export DataFrame to CSV
df.to_csv('grades.csv', index=False)

# %%
type(df)

# numpy.ndarray

# %%
df.head(4) # top part of a df plus num of rows u put in column
            # 5 is a default argument
df.tail() # below part of a df

# %%
# we can access certain columns in dataframes too

df.max()

# %%
import numpy as np
arrayyy = np.array([])
type(arrayyy)

# %%
# series

marks_series = pd.Series([])
type(marks_series)

# %%
df

# %%
df.english

# %%
ali = df['name'][2]
english_Ali = df['english'][2]
print(f'In English {ali} had {english_Ali} marks')

# %%
# core data types we use in pandas?

# dataframe
# series

# %% [markdown]
# ### create a series of data pd.series 5 values of temperature
# ### datafame city and temperature - cities

# %%
city_temp = {'city':['Kuala Lumpur','Mumbai','Sydney','Tokyo','London'],
             'temperature':['31°C','32°C','22°C','16°C','11°C']}

print(city_temp)
# Out:
# {'city': ['Kuala Lumpur', 'Mumbai', 'Sydney', 'Tokyo', 'London'], 'temperature': ['31°C', '32°C', '22°C', '16°C', '11°C']}

# %%
ctdf = pd.DataFrame(city_temp)

ctdf

ctdf
# Out:
#            city temperature
# 0  Kuala Lumpur        31°C
# 1        Mumbai        32°C
# 2        Sydney        22°C
# 3         Tokyo        16°C
# 4        London        11°C

# %%
ctdf2 = ctdf

ctdf2['city_temp'] = city_temp

ctdf2
# Out:
#            city temperature city_temp
# 0  Kuala Lumpur        31°C       NaN
# 1        Mumbai        32°C       NaN
# 2        Sydney        22°C       NaN
# 3         Tokyo        16°C       NaN
# 4        London        11°C       NaN

# %%
temp11 = pd.Series([31,32,22,16,11])
print('Type of temp11: ',type(temp11))

temperatures = {
    'cities':['KL','MB','SDY','TKY','LDN'],
    'temp10':[31,32,22,16,11]
}

temp_df=pd.DataFrame(temperatures)
print('type of temp_df: ',type(temp_df))

print(temp_df)
print(temp11)
# Out:
# Type of temp11:  <class 'pandas.core.series.Series'>
# type of temp_df:  <class 'pandas.core.frame.DataFrame'>
#   cities  temp10
# 0     KL      31
# 1     MB      32
# 2    SDY      22
# 3    TKY      16
# 4    LDN      11
# 0    31
# 1    32
# 2    22
# 3    16
# 4    11
# dtype: int64

# %%
temp_df['temp11']=temp11

temp_df
# Out:
#   cities  temp10  temp11
# 0     KL      31      31
# 1     MB      32      32
# 2    SDY      22      22
# 3    TKY      16      16
# 4    LDN      11      11

# %%
data = {
    'cities':['KL','KL','KL','TKY','LDN'],
    'temp10':[31,32,22,16,11]
}

df = pd.DataFrame(data)
df
# Out:
#   cities  temp10
# 0     KL      31
# 1     KL      32
# 2     KL      22
# 3    TKY      16
# 4    LDN      11

# %%
df['cities'].value_counts()
# Out:
# cities
# KL     3
# TKY    1
# LDN    1
# Name: count, dtype: int64

# %%
df['cities'].unique()
# Out:
# array(['KL', 'TKY', 'LDN'], dtype=object)

# %%
df2 =df['cities'].drop_duplicates()
df2
# Out:
# 0     KL
# 3    TKY
# 4    LDN
# Name: cities, dtype: object
